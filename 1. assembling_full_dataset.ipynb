# %%
import time
import re
import mwclient
import pandas as pd
import json

# %% [markdown]
# # Step 1: Identify all categories that I will be using.

# %% [markdown]
# There are 6 subcategories: high, medium, low, top importance & NA / unknown importance.

# %% [markdown]
# # Step 2: Get all talk pages for one category.

# %%
user_agent = 'User-Agent (contact: zz102@wellesley.edu)'
site = mwclient.Site('en.wikipedia.org', clients_useragent=user_agent)

# 2. Access the Category
category = site.categories['High-importance_Health_and_fitness_articles']

"""
for p in category:
    print(p)
"""
talkPages = []
for p in category:
    talkPages.append(p.name)
len(talkPages)
# Out:
# 111

# %%
talkPages[:3]
# Out:
# ['Talk:996 working hour system',
#  'Talk:Active mobility',
#  'Talk:Aerobic conditioning']

# %% [markdown]
# 111 high importance articles.

# %%
user_agent = 'User-Agent (contact: zz102@wellesley.edu)'
site = mwclient.Site('en.wikipedia.org', clients_useragent=user_agent)

# 2. Access the Category
category = site.categories['Low-importance_Health_and_fitness_articles']

"""
for p in category:
    print(p)
"""
articleNames = []
for p in category:
    articleNames.append(p.name)
len(articleNames)
# Out:
# 1976

# %% [markdown]
# 1976 low-importance articles.

# %% [markdown]
# # Step 3: For each talk page, navigate to the actual page and save the page titles.

# %%
articleNames = []
for page in talkPages[:3]:
    talk_page = site.Pages[page]

    # 3. Get the Article (Subject) page
    # Logic: If it is a Talk page (Namespace 1), remove the "Talk:" prefix.
    if talk_page.namespace == 1:
        # 'Talk:Exercise' -> 'Exercise'
        article_title = talk_page.name.split(':', 1)[1]
        articleNames.append(article_title)

# %%
articleNames[:3]
# Out:
# ['996 working hour system', 'Active mobility', 'Aerobic conditioning']

# %% [markdown]
# # Step 4: After navigating to the actual page, extract relevant properties.

# %% [markdown]
# We want the usual page title and QID, but the short description is also a very helpful feature that we can use for zero-shot classification.

# %%
def getPageProps(articleName):
    "Returns an ordered nested dictionary after calling the api."
    page_title = articleName
    result = site.api(
        'query',
        prop='pageprops',
        titles=page_title,
        ppprop='wikibase_item'
    )
    return result

def flattenResults(result):
    "Inputs an Ordered Dict and Returns a flattened dictionary"
    return pd.json_normalize(result).to_dict('records')[0]

def extractProperties(flattenedDict):
    """"
    Takes in a flattened Dictionary and extracts the relevant information.
    Returns a dictionary of pageid, title, and wikibase_item.
    """
    newDict = {}
    # get the value associated with pageid, it's a list of keys so specify the first one
    pageid = [p for p in flattenedDict if p.endswith('pageid')][0] 
    title = [t for t in flattenedDict if t.endswith('title')][0]
    qid = [q for q in flattenedDict if q.endswith('wikibase_item')][0]

    newDict = {'pageid': flattenedDict[pageid], 
               'title': flattenedDict[title], 
               'qid': flattenedDict[qid]}
    return newDict

# %% [markdown]
# Now, we can put this code together.

# %%
raw_props = []
for p in articleNames:

    user_agent = 'User-Agent (contact: zz102@wellesley.edu)'
    site = mwclient.Site('en.wikipedia.org', clients_useragent=user_agent)

    raw_props.append(getPageProps(p))
    
clean_props = []
for item in raw_props:
    # 1. Process the item
    cleaned_item = extractProperties(flattenResults(item))
        
    # 2. Add the category name to the dictionary
    cleaned_item['category'] = 'high_importance'
        
    # 3. Append to final list
    clean_props.append(cleaned_item)

# %%
clean_props[:3]
# Out:
# [{'pageid': 60380397,
#   'title': '996 working hour system',
#   'qid': 'Q62568684',
#   'category': 'high_importance'},
#  {'pageid': 22570610,
#   'title': 'Active mobility',
#   'qid': 'Q4010939',
#   'category': 'high_importance'},
#  {'pageid': 2012158,
#   'title': 'Aerobic conditioning',
#   'qid': 'Q4688194',
#   'category': 'high_importance'}]

# %%
def getAllArticlesByCat(category_name):
    user_agent = 'User-Agent (contact: zz102@wellesley.edu)'
    site = mwclient.Site('en.wikipedia.org', clients_useragent=user_agent)
    category = site.categories[category_name]

    # Step 1: Get talk pages
    talkPages = [t.name for t in category]
    
    # Step 2: Get article names
    articleNames = []
    for p in talkPages:
        talk_page = site.Pages[p]
        if talk_page.namespace == 1:
            article_title = talk_page.name.split(':', 1)[1]
            articleNames.append(article_title)

    # Step 3: Get properties for each article
    raw_props = [getPageProps(a) for a in articleNames]

    # Step 4: Clean up results 
    clean_props = []
    for item in raw_props:
        try:
            cleaned_item = extractProperties(flattenResults(item))
            cleaned_item['category'] = category_name.split('_')[0]
            clean_props.append(cleaned_item)
        except Exception as e:
            print(f"Error processing {item}: {e}")
    return clean_props

# %%
'High-importance_Health_and_fitness_articles'.split('_')[0]
# Out:
# 'High-importance'

# %% [markdown]
# # Step 5: Loop through all categories.

# %%
categories = ['High-importance_Health_and_fitness_articles', "Low-importance_Health_and_fitness_articles", "Mid-importance_Health_and_fitness_articles", "NA-importance_Health_and_fitness_articles", "Top-importance_Health_and_fitness_articles", "Unknown-importance_Health_and_fitness_articles"]

# %% [markdown]
# There should be 6907 articles.

# %%
full_data = []

for c in categories:
    full_data.extend(getAllArticlesByCat(c))
# Out:
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'40950837': OrderedDict({'pageid': 40950837, 'ns': 0, 'title': 'Diarrhea in developing regions'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'1588686': OrderedDict({'pageid': 1588686, 'ns': 0, 'title': 'American Legacy Foundation'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81442807': OrderedDict({'pageid': 81442807, 'ns': 0, 'title': 'BinayTara'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'80766801': OrderedDict({'pageid': 80766801, 'ns': 0, 'title': 'Bladder diary'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'63303758': OrderedDict({'pageid': 63303758, 'ns': 0, 'title': 'Correct handwashing technique'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'39470028': OrderedDict({'pageid': 39470028, 'ns': 0, 'title': 'Electronic cigars'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'52683089': OrderedDict({'pageid': 52683089, 'ns': 0, 'title': 'List of CAHIIM-accredited HIM Programs in the United States'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81679349': OrderedDict({'pageid': 81679349, 'ns': 0, 'title': 'Meril'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81775182': OrderedDict({'pageid': 81775182, 'ns': 0, 'title': 'Muñoz SAFE Act'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'6243636': OrderedDict({'pageid': 6243636, 'ns': 0, 'title': 'Orgasmatron (massage device)'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'80982967': OrderedDict({'pageid': 80982967, 'ns': 0, 'title': 'Secondary attack rate'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'55344959': OrderedDict({'pageid': 55344959, 'ns': 0, 'title': 'Sedative, hypnotic, or anxiolytic use disorder'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'80885763': OrderedDict({'pageid': 80885763, 'ns': 0, 'title': 'Shared Health'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'2438153': OrderedDict({'pageid': 2438153, 'ns': 0, 'title': 'Signal (toothpaste)'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'25047000': OrderedDict({'pageid': 25047000, 'ns': 0, 'title': 'SilverSneakers'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81781895': OrderedDict({'pageid': 81781895, 'ns': 0, 'title': 'Smoking by country'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'60457371': OrderedDict({'pageid': 60457371, 'ns': 0, 'title': 'Sulfur soap'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'1946': OrderedDict({'pageid': 1946, 'ns': 0, 'title': 'Unit of alcohol'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'2462659': OrderedDict({'pageid': 2462659, 'ns': 0, 'title': 'Vitamin U'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'1141368': OrderedDict({'pageid': 1141368, 'ns': 0, 'title': 'Aerobic threshold'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81737607': OrderedDict({'pageid': 81737607, 'ns': 0, 'title': 'Fragile Minds'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81239193': OrderedDict({'pageid': 81239193, 'ns': 0, 'title': 'Good Psychiatric Management'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81441142': OrderedDict({'pageid': 81441142, 'ns': 0, 'title': 'Health Connect'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'76457565': OrderedDict({'pageid': 76457565, 'ns': 0, 'title': 'Index of articles related to COVID-19'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range
# Error processing OrderedDict({'batchcomplete': '', 'query': OrderedDict({'pages': OrderedDict({'81427555': OrderedDict({'pageid': 81427555, 'ns': 0, 'title': 'Therapeutic climbing'})}), 'userinfo': OrderedDict({'id': 0, 'name': '192.42.89.2', 'anon': ''})})}): list index out of range

# %%
len(full_data)
# Out:
# 3177

# %% [markdown]
# 3177 articles.

# %% [markdown]
# # Step 6: Save all data into a json file.

# %%
with open ('all_articles_by_importance.json', 'w') as f:
    json.dump(full_data, f)

# %%
data = []
with open ('all_articles_by_importance.json', 'r') as f:
    data = json.load(f)
data[:3]
# Out:
# [{'pageid': 60380397,
#   'title': '996 working hour system',
#   'qid': 'Q62568684',
#   'category': 'High-importance'},
#  {'pageid': 22570610,
#   'title': 'Active mobility',
#   'qid': 'Q4010939',
#   'category': 'High-importance'},
#  {'pageid': 2012158,
#   'title': 'Aerobic conditioning',
#   'qid': 'Q4688194',
#   'category': 'High-importance'}]
